# %% [markdown]
# <a href="https://colab.research.google.com/github/Sahlegiorgis/DS-Unit-1-Sprint-1-Data-Wrangling-and-Storytelling/blob/master/colab_intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Five ways to read your data into a colab notebook

# %% [markdown]
# [Keyboard shortcuts for colab](https://medium.com/@tuewithmorris/google-colab-notebooks-keyboard-shortcuts-aa6a008fb91b)

# %%
print('code!')
x = 35
y = 45
print( x * y)
# Out:
# code!
# 1575

# %%
import pandas as pd
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-12415eb9-627f-4977-87e2-95de5049ce94" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-12415eb9-627f-4977-87e2-95de5049ce94">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %% [markdown]
# #### Method 1. Read data directly from a URL.

# %%
# this is the simplest way to read in data
# source: # https://opendata.dc.gov/datasets/bike-trails/data
url = 'https://opendata.arcgis.com/datasets/e8c2b7ef54fb43d9a2ed1b0b75d0a14d_4.csv'
print(url)
# Out:
# https://opendata.arcgis.com/datasets/e8c2b7ef54fb43d9a2ed1b0b75d0a14d_4.csv

# %%
# use pandas
import pandas as pd
bikes = pd.read_csv(url)
bikes.head()
# Out:
#    OBJECTID     LENGTH                       NAME  ... Shape_Length MILES  ROUTEID
# 0         1    827.476       National Mall Trails  ...   252.214952   0.0      NaN
# 1         2  19225.404     Capital Crescent Trail  ...  5859.914940   0.0      NaN
# 2         3  25404.687           Rock Creek Trail  ...  7743.364240   0.0      NaN
# 3         4   6201.712  Metropolitan Branch Trail  ...  1890.285630   0.0      NaN
# 4         5  12625.091         Watts Branch Trail  ...  3848.135455   0.0      NaN
#
# [5 rows x 8 columns]

# %%
bikes.tail()
# Out:
#     OBJECTID     LENGTH  ...     MILES ROUTEID
# 85        86  16582.778  ...  3.140678    WEST
# 86        87  16582.778  ...  3.140678    WEST
# 87        88  16582.778  ...  3.140678    WEST
# 88        89      0.000  ...  0.000000    EAST
# 89        90      0.000  ...  0.000000    EAST
#
# [5 rows x 8 columns]

# %%
# Sometimes you have to supply the column heads.
column_headers = ['name', 'landmass', 'zone', 'area', 'population', 'language', 
                  'religion', 'bars', 'stripes', 'colours', 'red', 'green', 
                  'blue', 'gold', 'white', 'black', 'orange', 'mainhue', 
                  'circles', 'crosses', 'saltires', 'quarters', 'sunstars', 
                  'crescent', 'triangle', 'icon', 'animate', 'text', 'topleft', 
                  'botright']
flag_data_url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/flags/flag.data'

# %%
# open up the flags!
flags = pd.read_csv(flag_data_url, header=None, names=column_headers)
flags.head()
# Out:
#              name  landmass  zone  area  ...  animate  text  topleft  botright
# 0     Afghanistan         5     1   648  ...        0     0    black     green
# 1         Albania         3     1    29  ...        1     0      red       red
# 2         Algeria         4     1  2388  ...        0     0    green     white
# 3  American-Samoa         6     3     0  ...        1     0     blue       red
# 4         Andorra         3     1     0  ...        0     0     blue       red
#
# [5 rows x 30 columns]

# %%
# Let's try another example.
url='https://opendata.arcgis.com/datasets/2e65fc16edc3481989d2cc17e6f8c533_54.csv'
# source: https://opendata.dc.gov/datasets/museums-in-dc/data

# %%
museums = pd.read_csv(url)
museums.sample(5)
# Out:
#             X          Y  OBJECTID  ... MAR_LONGITUDE MAR_LATITUDE   MARID
# 79 -76.985179  38.863389        80  ...    -76.985177    38.863382  293207
# 6  -77.021696  38.895868         7  ...    -77.021694    38.895860  279777
# 75 -77.036037  38.925552        76  ...    -77.036034    38.925545  235878
# 48 -77.086853  38.939100        49  ...    -77.086851    38.939092  223996
# 78 -77.042603  38.894453        79  ...    -77.042600    38.894445  293214
#
# [5 rows x 12 columns]

# %% [markdown]
# ### Method 2. Read a file that is already in colab.

# %%
# So colab comes with some built in files.
cali = pd.read_csv('sample_data/california_housing_train.csv')
cali.head()
# Out:
#    longitude  latitude  ...  median_income  median_house_value
# 0    -114.31     34.19  ...         1.4936             66900.0
# 1    -114.47     34.40  ...         1.8200             80100.0
# 2    -114.56     33.69  ...         1.6509             85700.0
# 3    -114.57     33.64  ...         3.1917             73400.0
# 4    -114.57     33.57  ...         1.9250             65500.0
#
# [5 rows x 9 columns]

# %%
# you can also read a json file. Notice the difference in pandas method.
quartet = pd.read_json('sample_data/anscombe.json')
quartet.head()
# Out:
#   Series   X     Y
# 0      I  10  8.04
# 1      I   8  6.95
# 2      I  13  7.58
# 3      I   9  8.81
# 4      I  11  8.33

# %% [markdown]
# ### Method 3. Upload a file to colab.
# Reminder, uploaded files will get deleted when this runtime is recycled.

# %%
# You can also use the manual upload GUI over on the left of your screen.
snails = pd.read_csv('abalone.csv')
snails.head()
# Out:
#   Sex  Length  Diameter  ...  Viscera weight  Shell weight  Rings
# 0   M   0.455     0.365  ...          0.1010         0.150     15
# 1   M   0.350     0.265  ...          0.0485         0.070      7
# 2   F   0.530     0.420  ...          0.1415         0.210      9
# 3   M   0.440     0.365  ...          0.1140         0.155     10
# 4   I   0.330     0.255  ...          0.0395         0.055      7
#
# [5 rows x 9 columns]

# %%
# open the file
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7a1513e4-f900-4a21-9616-0a9e930eec15" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7a1513e4-f900-4a21-9616-0a9e930eec15">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving abalone.csv to abalone (1).csv

# %% [markdown]
# ###  Method 4. Read a file that's saved on github
# https://github.com/austinlasseter/dash-virginia-counties

# %%
# useful for reading raw data from github.
url='https://raw.githubusercontent.com/austinlasseter/dash-virginia-counties/master/resources/acs2017_county_data.csv'
# Source: https://github.com/austinlasseter/dash-virginia-counties/blob/master/resources/acs2017_county_data.csv

counties = pd.read_csv(url)
counties.head()
# Out:
#    CountyId    State          County  ...  SelfEmployed  FamilyWork  Unemployment
# 0      1001  Alabama  Autauga County  ...           5.6         0.1           5.2
# 1      1003  Alabama  Baldwin County  ...           6.3         0.1           5.5
# 2      1005  Alabama  Barbour County  ...           6.5         0.3          12.4
# 3      1007  Alabama     Bibb County  ...           6.3         0.3           8.2
# 4      1009  Alabama   Blount County  ...           4.0         0.1           4.9
#
# [5 rows x 37 columns]

# %%
take2 = pd.read_excel('https://github.com/austinlasseter/dash-virginia-counties/blob/master/resources/ruralurbancodes2013.xls?raw=true')
take2.head()
# Out:
#    FIPS State  ... RUCC_2013                                        Description
# 0  1001    AL  ...         2  Metro - Counties in metro areas of 250,000 to ...
# 1  1003    AL  ...         3  Metro - Counties in metro areas of fewer than ...
# 2  1005    AL  ...         6  Nonmetro - Urban population of 2,500 to 19,999...
# 3  1007    AL  ...         1  Metro - Counties in metro areas of 1 million p...
# 4  1009    AL  ...         1  Metro - Counties in metro areas of 1 million p...
#
# [5 rows x 6 columns]

# %% [markdown]
# ### Method 5. Read a zip file.

# %%
# use the 'bang' for bash shell scripting.
! pwd
! ls
# Out:
# /content
# 'abalone (1).csv'   abalone.csv   sample_data

# %%
# the 'wget' command reads content from the web.
# https://resources.lendingclub.com/LoanStats_2018Q4.csv.zip

! wget https://resources.lendingclub.com/LoanStats_2018Q4.csv.zip
# Out:
# --2020-07-08 02:40:25--  https://resources.lendingclub.com/LoanStats_2018Q4.csv.zip
# Resolving resources.lendingclub.com (resources.lendingclub.com)... 34.213.98.158, 54.148.162.195, 52.11.197.48, ...
# Connecting to resources.lendingclub.com (resources.lendingclub.com)|34.213.98.158|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘LoanStats_2018Q4.csv.zip’
#
# LoanStats_2018Q4.cs     [      <=>           ]  22.21M  1.86MB/s    in 13s
#
# 2020-07-08 02:40:39 (1.73 MB/s) - ‘LoanStats_2018Q4.csv.zip’ saved [23289953]

# %%
# how do you unzip a .zip file in bash?
! unzip LoanStats_2018Q4.csv.zip
# Out:
# Archive:  LoanStats_2018Q4.csv.zip
#   inflating: LoanStats_2018Q4.csv

# %%
# Now you can read that csv file into pandas.
loans = pd.read_csv('LoanStats_2018Q4.csv')
loans.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (0,1,2,3,4,7,13,18,19,24,25,27,28,29,30,31,32,34,36,37,38,39,40,41,42,43,44,46,49,50,51,53,54,56,57,58,59,60,61,62,63,64,65,66,67,68,69,70,71,72,73,74,75,76,77,78,79,80,81,82,83,84,85,86,87,88,89,90,91,92,93,94,95,96,97,98,99,100,101,102,103,104,105,106,107,108,109,110,111,113,114,115,116,117,118,119,120,121,126,127,131,132,134,135,136,141,142,143) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Notes offered by Prospectus (https://www.lendingclub.com/info/prospectus.action)
# id  member_id loan_amnt funded_amnt funded_amnt_inv term       int_rate installment grade sub_grade emp_title            emp_length home_ownership annual_inc verification_status issue_d  loan_status pymnt_plan url desc purpose            title                   zip_code addr_state dti   delinq_2yrs earliest_cr_line inq_last_6mths mths_since_last_delinq mths_since_last_record open_acc pub_rec revol_bal revol_util total_acc initial_list_status out_prncp out_prncp_inv total_pymnt     total_pymnt_inv total_rec_prncp total_rec_int total_rec_late_fee recoveries collection_recovery_fee last_pymnt_d last_pymnt_amnt next_pymnt_d last_credit_pull_d collections_12_mths_ex_med mths_since_last_major_derog policy_code application_type annual_inc_joint dti_joint verification_status_joint acc_now_delinq tot_coll_amt tot_cur_bal open_acc_6m open_act_il open_il_12m open_il_24m mths_since_rcnt_il total_bal_il il_util open_rv_12m open_rv_24m max_bal_bc all_util total_rev_hi_lim inq_fi total_cu_tl inq_last_12m acc_open_past_24mths avg_cur_bal bc_open_to_buy bc_util chargeoff_within_12_mths delinq_amnt mo_sin_old_il_acct mo_sin_old_rev_tl_op mo_sin_rcnt_rev_tl_op mo_sin_rcnt_tl mort_acc mths_since_recent_bc mths_since_recent_bc_dlq mths_since_recent_inq mths_since_recent_revol_delinq num_accts_ever_120_pd num_act
#               32000     32000       32000            60 months  14.47%  752.41      C     C2        Teacher              10+ years  MORTGAGE       110000     Source Verified     Dec-2018 Current     n          NaN NaN  home_improvement   Home improvement        152xx    PA         26.11 0           Oct-2000         0              24                     NaN                    18       0       14833     43%        32        w                   26017.15  26017.15      11247.56        11247.56        5982.85         5264.71       0.0                0.0        0.0                     May-2020     0.0             Jul-2020     Jun-2020           0                          41                          1           Individual       NaN              NaN       NaN                       0              273          73873       1           5           1           3           12                 59040        49      2           6           4293       46       34500            2      5           1            9                    4104        15794          41.1    0                        0           218                201                  6                     6              1        6                    41                       12                    41                             2                     7              11              8           11        15        13            16            11                  18       0                0            0                  3                  77.4           12.5             0                    0         94609           73873             26800          60109                      NaN             NaN                      NaN                    NaN              NaN              NaN                NaN                 NaN                   NaN                              NaN                                NaN                                 N             CVD19SKIP     INCOMECURT      COMPLETE        2             0               Apr-2020            Jun-2020          Apr-2020                2               0            ACTIVE               627.45                                     26278.58                       752.41                       N                    NaN                       NaN               NaN             NaN               NaN                                                                  NaN
#               5000      5000        5000             36 months  17.97%  180.69      D     D1        Administrative       6 years    MORTGAGE       59280      Source Verified     Dec-2018 Fully Paid  n          NaN NaN  debt_consolidation Debt consolidation      490xx    MI         10.51 0           Apr-2011         0              NaN                    NaN                    8        0       4599      19.1%      13        w                   0.00      0.00          5637.0527852364 5637.05         5000.00         622.05        15.0               0.0        0.0                     Oct-2019     4741.09         NaN          Jun-2020           0                          NaN                         1           Individual       NaN              NaN       NaN                       0              0            110299      0           1           0           2           14                 7150         72      0           2           0          35       24100            1      5           0            4                    18383       13800          0       0                        0           87                 92                   15                    14             2        77                   NaN                      14                    NaN                            0                     0              3               3           3         4         6             7             3                   8        0                0            0                  0                  100            0                0                    0         136927          11749             13800          10000                      NaN             NaN                      NaN                    NaN              NaN              NaN                NaN                 NaN                   NaN                              NaN                                NaN                                 N             NaN           NaN             NaN             NaN           NaN             NaN                 NaN               NaN                     NaN             NaN          NaN                  NaN                                        NaN                            NaN                          N                    NaN                       NaN               NaN             NaN               NaN                                                                  NaN

# %%
# You can also save back to csv, but remember to skip the index.

cali.head()
# Out:
#    longitude  latitude  ...  median_income  median_house_value
# 0    -114.31     34.19  ...         1.4936             66900.0
# 1    -114.47     34.40  ...         1.8200             80100.0
# 2    -114.56     33.69  ...         1.6509             85700.0
# 3    -114.57     33.64  ...         3.1917             73400.0
# 4    -114.57     33.57  ...         1.9250             65500.0
#
# [5 rows x 9 columns]

# %%
# save it back
cali.to_csv('cali2.csv', index=False)

# %%
cali2 = pd.read_csv('cali2.csv')
cali2.head()
# Out:
#    longitude  latitude  ...  median_income  median_house_value
# 0    -114.31     34.19  ...         1.4936             66900.0
# 1    -114.47     34.40  ...         1.8200             80100.0
# 2    -114.56     33.69  ...         1.6509             85700.0
# 3    -114.57     33.64  ...         3.1917             73400.0
# 4    -114.57     33.57  ...         1.9250             65500.0
#
# [5 rows x 9 columns]
